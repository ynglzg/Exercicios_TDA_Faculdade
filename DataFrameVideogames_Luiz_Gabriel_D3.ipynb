# %% [markdown]
# <a href="https://colab.research.google.com/github/ynglzg/Exercicios_TDA_Faculdade/blob/main/DataFrameVideogames_Luiz_Gabriel_D3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando a biblioteca

# %%
import pandas as pd # importando a biblioteca para poder utilizar seus métodos

# %% [markdown]
# # Criando as listas

# %%
nomes_jogos = ["Zelda Ocarina of Time", "Dark Souls 3", "The Witcher 3", "Hollow Knight", "Pokémon X", "Elden Ring", "Super Mario Odyssey", "Metal Gear 3", "Persona 5"]
dev_jogos = ["Nintendo", "From Software", "CD Projekt Red", "Team Cherry", "Nintendo", "From Software", "Nintendo", "Konami", "Atlus"]
genero_jogos = ["Aventura", "RPG", "RPG", "Plataforma", "RPG", "RPG", "Plataforma", "FPS", "RPG"]
plataforma_jogos = ["N64", "PS4", "PS4", "PC", "3ds", "PC", "Switch", "PS2", "PS3"]
duracao_jogos = [30, 48, 103, 41, 70, 100, 27, 20, 113] # Fonte: https://howlongtobeat.com/
ano_jogos = [1998, 2016, 2015, 2017, 2013, 2022, 2017, 2004, 2016]

# %% [markdown]
# # Criando o dicionário e o DataFrame

# %%
dicionario_jogos = {
    "Nome": nomes_jogos,
    "Desenvolvedora": dev_jogos,
    "Gênero": genero_jogos,
    "Plataforma": plataforma_jogos,
    "Duração (h)": duracao_jogos,
    "Ano": ano_jogos
    }

# %%
# Criando o DataFrame
df_videogames = pd.DataFrame(dicionario_jogos)
df_videogames
# Out:
#                     Nome  Desenvolvedora      Gênero Plataforma  Duração (h)  \
# 0  Zelda Ocarina of Time        Nintendo    Aventura        N64           30
# 1           Dark Souls 3   From Software         RPG        PS4           48
# 2          The Witcher 3  CD Projekt Red         RPG        PS4          103
# 3          Hollow Knight     Team Cherry  Plataforma         PC           41
# 4              Pokémon X        Nintendo         RPG        3ds           70
# 5             Elden Ring   From Software         RPG         PC          100
# 6    Super Mario Odyssey        Nintendo  Plataforma     Switch           27
# 7           Metal Gear 3          Konami         FPS        PS2           20
# 8              Persona 5           Atlus         RPG        PS3          113
#
#     Ano
# 0  1998
# 1  2016
# 2  2015
# 3  2017
# 4  2013
# 5  2022
# 6  2017
# 7  2004
# 8  2016

# %% [markdown]
# # Questão 1: Apresente em tela (output) toda a base de dados.

# %%
display(df_videogames) # ou print(df_videogames)

# %% [markdown]
# # Questão 2: Apresente o tamanho do seu dataframe (quantas colunas x linhas).

# %%
print(f"Tamanho: {df_videogames.shape}")
# Out:
# Tamanho: (9, 6)

# %% [markdown]
# # Questão 3: Acesse a linha (x) e apresente em tela todas as características do item.

# %%
display(df_videogames.loc[[5]]) # ou print(df_videogames.loc[0])

# Obs.: [] é indexador de listas, já [[]] é o indexador de matrizes
# ou seja, o primeiro printa o objeto inteiro e o segundo printa as colunas e linhas de forma organizada
# Out:
#          Nome Desenvolvedora Gênero Plataforma  Duração (h)   Ano
# 5  Elden Ring  From Software    RPG         PC          100  2022

# %% [markdown]
# # Questão 4: Verifique se o dataframe está vazio.

# %%
def esta_vazio(df):
    if df.empty:
        return "Sim"
    else:
        return "Não"

print(f"Está vazio: {esta_vazio(df_videogames)}")
# Out:
# Está vazio: Não

# %% [markdown]
# # Questão 5: Apresente em tela os 5 primeiros registros da base de dados.

# %%
display(df_videogames.head(5)) # head() imprime as linhas do 0 até à especificada no parâmetro.
# Out:
#                     Nome  Desenvolvedora      Gênero Plataforma  Duração (h)  \
# 0  Zelda Ocarina of Time        Nintendo    Aventura        N64           30
# 1           Dark Souls 3   From Software         RPG        PS4           48
# 2          The Witcher 3  CD Projekt Red         RPG        PS4          103
# 3          Hollow Knight     Team Cherry  Plataforma         PC           41
# 4              Pokémon X        Nintendo         RPG        3ds           70
#
#     Ano
# 0  1998
# 1  2016
# 2  2015
# 3  2017
# 4  2013

# %% [markdown]
# # Questão 6: Exclua um item (linha) de sua base de dados.

# %%
display(df_videogames.drop([1])) # por padrão, o método drop() apenas retorna a lista modificada, porém com o parâmetro inplace = True, ele passa a alterar o DataFrame original.
# Out:
#                     Nome  Desenvolvedora      Gênero Plataforma  Duração (h)  \
# 0  Zelda Ocarina of Time        Nintendo    Aventura        N64           30
# 2          The Witcher 3  CD Projekt Red         RPG        PS4          103
# 3          Hollow Knight     Team Cherry  Plataforma         PC           41
# 4              Pokémon X        Nintendo         RPG        3ds           70
# 5             Elden Ring   From Software         RPG         PC          100
# 6    Super Mario Odyssey        Nintendo  Plataforma     Switch           27
# 7           Metal Gear 3          Konami         FPS        PS2           20
# 8              Persona 5           Atlus         RPG        PS3          113
#
#     Ano
# 0  1998
# 2  2015
# 3  2017
# 4  2013
# 5  2022
# 6  2017
# 7  2004
# 8  2016

# %% [markdown]
# # Questão 7: Adicione um item (linha) na sua base de dados.

# %%
df_videogames.loc[-1] = ["Sekiro", "From Software", "Ação", "PS4", 30, 2019] # adiciona a nova linha com informações no final do DataFrame
df_videogames.index = df_videogames.index + 1 # adiciona um índice a mais
df_videogames = df_videogames.sort_index() # reorganiza o DataFrame por índice, fazendo com que a nova linha fique no índice 0
display(df_videogames)
# Out:
#                     Nome  Desenvolvedora      Gênero Plataforma  Duração (h)  \
# 0                 Sekiro   From Software        Ação        PS4           30
# 1  Zelda Ocarina of Time        Nintendo    Aventura        N64           30
# 2           Dark Souls 3   From Software         RPG        PS4           48
# 3          The Witcher 3  CD Projekt Red         RPG        PS4          103
# 4          Hollow Knight     Team Cherry  Plataforma         PC           41
# 5              Pokémon X        Nintendo         RPG        3ds           70
# 6             Elden Ring   From Software         RPG         PC          100
# 7    Super Mario Odyssey        Nintendo  Plataforma     Switch           27
# 8           Metal Gear 3          Konami         FPS        PS2           20
# 9              Persona 5           Atlus         RPG        PS3          113
#
#     Ano
# 0  2019
# 1  1998
# 2  2016
# 3  2015
# 4  2017
# 5  2013
# 6  2022
# 7  2017
# 8  2004
# 9  2016

# %% [markdown]
# # Questão 8: Transponha a coluna para a linha em sua base de dados.

# %%
display(df_videogames.T) # o método T realiza a transposição do quadro de dados (trocar as colunas com as linhas)
# Out:
#                             0                      1              2  \
# Nome                   Sekiro  Zelda Ocarina of Time   Dark Souls 3
# Desenvolvedora  From Software               Nintendo  From Software
# Gênero                   Ação               Aventura            RPG
# Plataforma                PS4                    N64            PS4
# Duração (h)                30                     30             48
# Ano                      2019                   1998           2016
#
#                              3              4          5              6  \
# Nome             The Witcher 3  Hollow Knight  Pokémon X     Elden Ring
# Desenvolvedora  CD Projekt Red    Team Cherry   Nintendo  From Software
# Gênero                     RPG     Plataforma        RPG            RPG
# Plataforma                 PS4             PC        3ds             PC
# Duração (h)                103             41         70            100
# Ano                       2015           2017       2013           2022
#
#                                   7             8          9
# Nome            Super Mario Odyssey  Metal Gear 3  Persona 5
# Desenvolvedora             Nintendo        Konami      Atlus
# Gênero                   Plataforma           FPS        RPG
# Plataforma                   Switch           PS2        PS3
# Duração (h)                      27            20        113
# Ano                            2017          2004       2016

# %% [markdown]
# # Questão 9: Apresente em tela somente a 1ª e a 2ª coluna (rótulo) da base de dados.

# %%
display(df_videogames.iloc[:, [0, 1]]) # ou display(df_videogames.loc[:, ["Nome", "Desenvolvedora"]]), caso já saiba o rótulo das colunas
# iloc == localizar colunas em uma posição (inteiro) específica, útil quando não se sabe o nome das colunas mas sim o índice
# : == para selecionar todas as linhas da posicao 0 até o final
# [0, 1] == índices das colunas que quero trazer
# Out:
#                     Nome  Desenvolvedora
# 0                 Sekiro   From Software
# 1  Zelda Ocarina of Time        Nintendo
# 2           Dark Souls 3   From Software
# 3          The Witcher 3  CD Projekt Red
# 4          Hollow Knight     Team Cherry
# 5              Pokémon X        Nintendo
# 6             Elden Ring   From Software
# 7    Super Mario Odyssey        Nintendo
# 8           Metal Gear 3          Konami
# 9              Persona 5           Atlus

# %% [markdown]
# # Questão: 10 Informe como foi desenvolvido o Projeto.
# Você deve fornecer uma breve descrição de como o projeto foi desenvolvido, quais técnicas e
# ferramentas foram utilizadas, e quais foram os principais desafios encontrados durante o
# desenvolvimento.

# %%
# Questão 10
# Escolhi esse tema por já ter conhecimento prévio, facilitando ao implementar os dados no DataFrame.
# Resolvi construir listas e em seguida transformá-las em um dicionário pois essa foi a forma que achei mais conveniente e lógica, sempre usando métodos da biblioteca pandas para manipular os dados.
# Dentre desafios do desenvolvimento, o mais complicado foi aprender as especificidades de cada método da biblioteca, tendo como base a documentação oficial do Pandas e o fórum Stack Overflow

# %% [markdown]
# # Extra: métodos comumente utilizados

# %%
print(f"Índices: {df_videogames.index}") # imprime os índices do DataFrame
print(f"Colunas: {df_videogames.columns}") # imprime as colunas do DataFrame
print(f"Dimensões: {df_videogames.ndim}") # imprime o número de dimensões do DataFrame
print(f"Formato: {df_videogames.shape}") # imprime número de linhas e colunas do DataFrame
print(f"Tamanho: {df_videogames.size}") # imprime o tamanho (colunas * linhas) do DataFrame
print(f"Está vazio: {df_videogames.empty}") # imprime um booleano que diz se o DataFrame está vazio
# Out:
# Índices: RangeIndex(start=0, stop=9, step=1)
# Colunas: Index(['Nome', 'Desenvolvedora', 'Gênero', 'Plataforma', 'Duração (h)', 'Ano'], dtype='object')
# Dimensões: 2
# Formato: (9, 6)
# Tamanho: 54
# Está vazio: False
